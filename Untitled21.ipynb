# %%
import pandas as pd
import numpy as np
df=pd.read_csv('heart.csv')
print(df.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
from sklearn.neighbors import KNeighborsClassifier
classifier= KNeighborsClassifier(n_neighbors=5, metric='manhattan')
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
y_pred1=classifier.predict(x_train)
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print('Test Accuracy:',acc*100)
acc1=accuracy_score(y_train,y_pred1)
print('Train accuracy:',acc1*100)
# Out:
# Test Accuracy: 78.53658536585367
# Train accuracy: 92.6829268292683

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping

model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation='relu', input_shape=(13,)),
  tf.keras.layers.Dense(3, activation='softmax')])
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history=model.fit(x_train, y_train, epochs=390, batch_size=32,validation_split=0.2,callbacks=[early_stopping])

training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
print('Training accuracy:',training_accuracy[-1]*100)
print('Validation accuracy:',validation_accuracy[-1]*100)
# Out:
# Epoch 1/390
# 21/21 [==============================] - 1s 18ms/step - loss: 53.8638 - accuracy: 0.0427 - val_loss: 41.1771 - val_accuracy: 0.1159
# Epoch 2/390
# 21/21 [==============================] - 0s 6ms/step - loss: 28.3179 - accuracy: 0.3003 - val_loss: 18.8246 - val_accuracy: 0.2866
# Epoch 3/390
# 21/21 [==============================] - 0s 6ms/step - loss: 9.2095 - accuracy: 0.4192 - val_loss: 3.1455 - val_accuracy: 0.5976
# Epoch 4/390
# 21/21 [==============================] - 0s 9ms/step - loss: 2.4551 - accuracy: 0.6433 - val_loss: 1.9342 - val_accuracy: 0.6280
# Epoch 5/390
# 21/21 [==============================] - 0s 5ms/step - loss: 1.7988 - accuracy: 0.6860 - val_loss: 1.7047 - val_accuracy: 0.6280
# Epoch 6/390
# 21/21 [==============================] - 0s 3ms/step - loss: 1.6064 - accuracy: 0.7088 - val_loss: 1.6226 - val_accuracy: 0.6341
# Epoch 7/390
# 21/21 [==============================] - 0s 4ms/step - loss: 1.5099 - accuracy: 0.7058 - val_loss: 1.4940 - val_accuracy: 0.6463
# Epoch 8/390
# 21/21 [==============================] - 0s 3ms/step - loss: 1.3913 - accuracy: 0.7149 - val_loss: 1.4086 - val_accuracy: 0.6524
# Epoch 9/390
# 21/21 [==============================] - 0s 4ms/step - loss: 1.2787 - accuracy: 0.7104 - val_loss: 1.2684 - val_accuracy: 0.6890
# Epoch 10/390
# 21/21 [==============================] - 0s 3ms/step - loss: 1.1527 - accuracy: 0.7256 - val_loss: 1.1452 - val_accuracy: 0.6829
# Epoch 11/390
# 21/21 [==============================] - 0s 3ms/step - loss: 1.0465 - accuracy: 0.7302 - val_loss: 1.0179 - val_accuracy: 0.6829
# Epoch 12/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.9480 - accuracy: 0.7195 - val_loss: 0.9352 - val_accuracy: 0.7195
# Epoch 13/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.8454 - accuracy: 0.7348 - val_loss: 0.8458 - val_accuracy: 0.7073
# Epoch 14/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.7683 - accuracy: 0.7439 - val_loss: 0.7780 - val_accuracy: 0.7012
# Epoch 15/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.7022 - accuracy: 0.7470 - val_loss: 0.8142 - val_accuracy: 0.7012
# Epoch 16/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.6121 - accuracy: 0.7622 - val_loss: 0.6972 - val_accuracy: 0.7134
# Epoch 17/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5633 - accuracy: 0.7851 - val_loss: 0.6287 - val_accuracy: 0.7012
# Epoch 18/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5562 - accuracy: 0.7759 - val_loss: 0.5859 - val_accuracy: 0.7500
# Epoch 19/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5077 - accuracy: 0.7790 - val_loss: 0.5604 - val_accuracy: 0.7378
# Epoch 20/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4976 - accuracy: 0.8049 - val_loss: 0.5643 - val_accuracy: 0.7622
# Epoch 21/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4868 - accuracy: 0.7820 - val_loss: 0.5363 - val_accuracy: 0.7378
# Epoch 22/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4742 - accuracy: 0.8125 - val_loss: 0.6063 - val_accuracy: 0.7134
# Epoch 23/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4406 - accuracy: 0.8171 - val_loss: 0.5258 - val_accuracy: 0.7866
# Epoch 24/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4317 - accuracy: 0.8262 - val_loss: 0.5292 - val_accuracy: 0.7805
# Epoch 25/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4195 - accuracy: 0.8277 - val_loss: 0.5463 - val_accuracy: 0.7561
# Epoch 26/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4426 - accuracy: 0.8110 - val_loss: 0.4767 - val_accuracy: 0.7561
# Epoch 27/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4228 - accuracy: 0.8171 - val_loss: 0.5024 - val_accuracy: 0.7988
# Epoch 28/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8232 - val_loss: 0.4956 - val_accuracy: 0.7988
# Epoch 29/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4105 - accuracy: 0.8399 - val_loss: 0.4569 - val_accuracy: 0.7866
# Epoch 30/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4060 - accuracy: 0.8415 - val_loss: 0.4528 - val_accuracy: 0.7805
# Epoch 31/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4008 - accuracy: 0.8399 - val_loss: 0.5347 - val_accuracy: 0.7622
# Epoch 32/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4131 - accuracy: 0.8262 - val_loss: 0.4513 - val_accuracy: 0.7622
# Epoch 33/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4131 - accuracy: 0.8338 - val_loss: 0.4658 - val_accuracy: 0.7500
# Epoch 34/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4480 - accuracy: 0.7957 - val_loss: 0.4588 - val_accuracy: 0.8049
# Epoch 35/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4038 - accuracy: 0.8308 - val_loss: 0.4808 - val_accuracy: 0.7805
# Epoch 36/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3861 - accuracy: 0.8537 - val_loss: 0.4370 - val_accuracy: 0.7927
# Epoch 37/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4276 - accuracy: 0.8262 - val_loss: 0.4571 - val_accuracy: 0.7988
# Epoch 38/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4330 - accuracy: 0.8095 - val_loss: 0.4759 - val_accuracy: 0.7866
# Epoch 39/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.8415 - val_loss: 0.4485 - val_accuracy: 0.8049
# Epoch 40/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3773 - accuracy: 0.8521 - val_loss: 0.4388 - val_accuracy: 0.8171
# Epoch 41/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3793 - accuracy: 0.8598 - val_loss: 0.4279 - val_accuracy: 0.7866
# Epoch 42/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3792 - accuracy: 0.8521 - val_loss: 0.4565 - val_accuracy: 0.7927
# Epoch 43/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3750 - accuracy: 0.8537 - val_loss: 0.4294 - val_accuracy: 0.8049
# Epoch 44/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3770 - accuracy: 0.8643 - val_loss: 0.4240 - val_accuracy: 0.8049
# Epoch 45/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3785 - accuracy: 0.8415 - val_loss: 0.4503 - val_accuracy: 0.7927
# Epoch 46/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3708 - accuracy: 0.8567 - val_loss: 0.4245 - val_accuracy: 0.7866
# Epoch 47/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4176 - accuracy: 0.8079 - val_loss: 0.4593 - val_accuracy: 0.7927
# Epoch 48/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3790 - accuracy: 0.8476 - val_loss: 0.4216 - val_accuracy: 0.8110
# Epoch 49/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3856 - accuracy: 0.8582 - val_loss: 0.4221 - val_accuracy: 0.7805
# Epoch 50/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3926 - accuracy: 0.8384 - val_loss: 0.4235 - val_accuracy: 0.7744
# Epoch 51/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3920 - accuracy: 0.8369 - val_loss: 0.4281 - val_accuracy: 0.7988
# Epoch 52/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3727 - accuracy: 0.8582 - val_loss: 0.4218 - val_accuracy: 0.8110
# Epoch 53/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 0.8598 - val_loss: 0.4195 - val_accuracy: 0.8110
# Epoch 54/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3751 - accuracy: 0.8460 - val_loss: 0.4172 - val_accuracy: 0.7744
# Epoch 55/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3732 - accuracy: 0.8476 - val_loss: 0.4206 - val_accuracy: 0.7927
# Epoch 56/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3719 - accuracy: 0.8445 - val_loss: 0.4142 - val_accuracy: 0.7927
# Epoch 57/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8460 - val_loss: 0.4149 - val_accuracy: 0.8110
# Epoch 58/390
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3754 - accuracy: 0.8506 - val_loss: 0.4132 - val_accuracy: 0.8110
# Epoch 59/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.8521 - val_loss: 0.4713 - val_accuracy: 0.7866
# Epoch 60/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3617 - accuracy: 0.8567 - val_loss: 0.4553 - val_accuracy: 0.7927
# Epoch 61/390
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3638 - accuracy: 0.8521 - val_loss: 0.4133 - val_accuracy: 0.8110
# Epoch 62/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3697 - accuracy: 0.8537 - val_loss: 0.4138 - val_accuracy: 0.7988
# Epoch 63/390
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 0.8491 - val_loss: 0.4447 - val_accuracy: 0.7927
# Training accuracy: 84.90853905677795
# Validation accuracy: 79.2682945728302

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
test_loss, test_acc = model.evaluate(x_test,y_test)
print('New test accuracy:', test_acc*100)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3131 - accuracy: 0.8634
# New test accuracy: 86.34146451950073

# %%
df4 = {
    'age': int(input("Enter your age: ")),
    'sex': int(input("Enter your sex (1: male, 0: female): ")),
    'cp': int(input("Enter chest pain type (0: typical angina, 1: atypical anginaValue, 2: non-anginal pain, 3: asymptomatic): ")),
    'trestbps': int(input("Enter resting blood pressure (in mm Hg): ")),
    'chol': int(input("Enter serum cholesterol in mg/dl: ")),
    'fbs': int(input("Enter fasting blood sugar > 120 mg/dl (1: true, 0: false): ")),
    'restecg': int(input("Enter resting electrocardiographic results (0: normal, 1: having ST-T wave abnormality, 2: showing probable or definite left ventricular hypertrophy): ")),
    'thalach': int(input("Enter maximum heart rate achieved: ")),
    'exang': int(input("Enter exercise induced angina (1: yes, 0: no): ")),
    'oldpeak': float(input("Enter ST depression induced by exercise relative to rest: ")),
    'slope': int(input("Enter the slope of the peak exercise ST segment (0: upsloping, 1: flat 2: downsloping): ")),
    'ca': int(input("Enter number of major vessels colored by fluoroscopy (0-3): ")),
    'thal': int(input("Enter thalassemia (1: normal, 2: fixed defect, 3: reversable defect): "))
}
df4=pd.DataFrame(df4,index=[0])
prediction=classifier.predict(df4)
print(prediction)
if(prediction[0]==0):
  print("No Chance of Heart Disease")
else:
  print("Chance of Heart Disease")
# Out:
# Enter your age: 58
# Enter your sex (1: male, 0: female): 0
# Enter chest pain type (0: typical angina, 1: atypical anginaValue, 2: non-anginal pain, 3: asymptomatic): 0
# Enter resting blood pressure (in mm Hg): 100
# Enter serum cholesterol in mg/dl: 248
# Enter fasting blood sugar > 120 mg/dl (1: true, 0: false): 0
# Enter resting electrocardiographic results (0: normal, 1: having ST-T wave abnormality, 2: showing probable or definite left ventricular hypertrophy): 0
# Enter maximum heart rate achieved: 122
# Enter exercise induced angina (1: yes, 0: no): 0
# Enter ST depression induced by exercise relative to rest: 1
# Enter the slope of the peak exercise ST segment (0: upsloping, 1: flat 2: downsloping): 1
# Enter number of major vessels colored by fluoroscopy (0-3): 0
# Enter thalassemia (1: normal, 2: fixed defect, 3: reversable defect): 2
# [1]
# Chance of Heart Disease

# %%
p=classifier.predict_proba(df4)
for i in p:
  for j in i:
    if(j>0.5):
      print("Probability percentage of Heart Disease:",j*100)
    else:
      print("Probabilty percentage of No Heart Disease:",j*100)
# Out:
# Probabilty percentage of No Heart Disease: 40.0
# Probability percentage of Heart Disease: 60.0
